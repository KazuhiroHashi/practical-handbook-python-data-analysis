# %% [markdown]
# # XML形式

# %% [markdown]
# ## データサンプル

# %% [markdown]
# ## XML形式のデータを読み込む

# %%
import xml.etree.ElementTree as ET

tree = ET.parse("data/ueno-map.kml")
root = tree.getroot()

# %%
namespace = "{http://www.opengis.net/kml/2.2}"
name = root[0].find(f"{namespace}name").text
name
# Out:
# '上野駅周辺飲食店'

# %%
folders = root[0].findall(f"{namespace}Folder")  # Folderノードを取得  # ・・①
out = []
for i, folder in enumerate(folders):  # Folderノードを繰り返し処理
    folder_name = folder.find(
        f"{namespace}name"
    ).text  # Folderノードのnameがカテゴリー名  # ・・②

    shops = folder.findall(f"{namespace}Placemark")  # 店舗の情報にアクセス
    shops_list = []
    for shop in shops:  # ・・③
        shop_name = shop.find(f"{namespace}name").text  # 店舗の名称を取得
        coordinates = (
            shop.find(f"{namespace}Point")
            .find(f"{namespace}coordinates")
            .text  # ・・④
        )  # 経度、緯度、高度の情報を取得
        lon, lat, alt = [
            s.strip() for s in coordinates.split(",", 2)  # ・・⑤
        ]  # 情報を分割
        # 店舗の情報を辞書にしてリストに追記
        shops_list.append(  # ・・⑥
            {
                "name": shop_name,
                "lon": lon,
                "lat": lat,
                "alt": alt,
            }
        )

    # カテゴリーごとの情報を辞書型にして、リストに追記
    out.append(  # ・・⑦
        {
            "id": i + 1,
            "name": folder_name,
            "shops": shops_list,
        }
    )
out
# Out:
# [{'id': 1,
#   'name': 'ラーメン屋',
#   'shops': [{'name': '東京じゃんがら ecute上野店',
#     'lon': '139.7771312',
#     'lat': '35.7140434',
#     'alt': '0'},
#    {'name': '博多ラーメン 長浜や 上野店',
#     'lon': '139.7775269',
#     'lat': '35.7124554',
#     'alt': '0'},
#    {'name': "T'sたんたん エキュート上野店",
#     'lon': '139.7771408',
#     'lat': '35.7140681',
#     'alt': '0'},
#    {'name': '鯛塩そば灯花 アトレ上野店',
#     'lon': '139.7770178',
#     'lat': '35.7133078',
#     'alt': '0'},
#    {'name': '横浜家系ラーメン 壱角家 上野店',
#     'lon': '139.7778759',
#     'lat': '35.7123833',
#     'alt': '0'},
#    {'name': '麺屋 天王', 'lon': '139.7797678', 'lat': '35.7141222', 'alt': '0'},
#    {'name': '一蘭 アトレ上野山下口店',
#     'lon': '139.7752174',
#     'lat': '35.7124196',
#     'alt': '0'},
#    {'name': 'らーめん花の華 上野店',
#     'lon': '139.7788319',
#     'lat': '35.7121706',
#     'alt': '0'},
#    {'name': '六厘舎 上野店', 'lon': '139.7750484', 'lat': '35.7121834', 'alt': '0'},
#    {'name': '横浜家系ラーメン希家 上野店',
#     'lon': '139.7786098',
#     'lat': '35.7118269',
#     'alt': '0'}]},
#  {'id': 2,
#   'name': 'カレー屋',
#   'shops': [{'name': 'シターラ ダイナー エキュート上野店（SITAARA DINER）',
#     'lon': '139.776792',
#     'lat': '35.7132653',
#     'alt': '0'},
#    {'name': 'マイカリー食堂 上野店',
#     'lon': '139.778374',
#     'lat': '35.712958',
#     'alt': '0'},
#    {'name': 'インド・ネパール料理&バー ナマステ上野キッチン（Namaste UENO Kitchen）',
#     'lon': '139.779736',
#     'lat': '35.714079',
#     'alt': '0'},
#    {'name': 'カレー専門店 クラウンエース 上野アメ横店',
#     'lon': '139.7750854',
#     'lat': '35.7112609',
#     'alt': '0'},
#    {'name': 'スルタン 東上野店',
#     'lon': '139.7828001',
#     'lat': '35.7155242',
#     'alt': '0'},
#    {'name': 'Re Nepaka(ネパカ)上野店',
#     'lon': '139.7802984',
#     'lat': '35.7107611',
#     'alt': '0'},
#    {'name': 'カレーの店 サカエヤ',
#     'lon': '139.7800917',
#     'lat': '35.7073677',
#     'alt': '0'},
#    {'name': 'カレー clover(くろーばー)',
#     'lon': '139.7709038',
#     'lat': '35.7062837',
#     'alt': '0'},
#    {'name': 'ゴーゴーカレー 上野御徒町店',
#     'lon': '139.7754455',
#     'lat': '35.708453',
#     'alt': '0'},
#    {'name': 'ラッフルズカリー',
#     'lon': '139.778286',
#     'lat': '35.7073153',
#     'alt': '0'}]},
#  {'id': 3,
#   'name': '焼肉屋',
#   'shops': [{'name': 'ブ厚い焼肉 焼肉フジ 上野駅前本店',
#     'lon': '139.7790501',
#     'lat': '35.7138809',
#     'alt': '0'},
#    {'name': '焼肉 USHIHACHI 上野店',
#     'lon': '139.777376',
#     'lat': '35.712613',
#     'alt': '0'},
#    {'name': '絵のある街 上野店',
#     'lon': '139.7755379',
#     'lat': '35.7109052',
#     'alt': '0'},
#    {'name': '焼肉陽山道 上野駅前店',
#     'lon': '139.7755765',
#     'lat': '35.7098862',
#     'alt': '0'},
#    {'name': '和家 NAGOMIYA 上野店',
#     'lon': '139.7751193',
#     'lat': '35.7107406',
#     'alt': '0'},
#    {'name': '焼肉ホルモン本舗 炎 上野駅前店',
#     'lon': '139.7762069',
#     'lat': '35.7112493',
#     'alt': '0'},
#    {'name': '肉の街 上野本店', 'lon': '139.775175', 'lat': '35.711006', 'alt': '0'},
#    {'name': '太昌園上野駅前店', 'lon': '139.7754445', 'lat': '35.7104037', 'alt': '0'},
#    {'name': '焼肉ひだり', 'lon': '139.7810698', 'lat': '35.711169', 'alt': '0'},
#    {'name': '土古里 上野バンブーガーデン店',
#     'lon': '139.7745426',
#     'lat': '35.7124233',
#     'alt': '0'}]}]

# %% [markdown]
# ## pandasのオブジェクトに変換する

# %%
import pandas as pd

df = pd.json_normalize(
    out,
    record_path="shops",
    meta=["name"],
    record_prefix="shop.",
)

# %%
import pandas as pd

df = pd.json_normalize(
    out,
    record_path="shops",
    meta=["name"],
    record_prefix="shop.",
)

# %%
df.head()
# Out:
#           shop.name     shop.lon    shop.lat shop.alt   name
# 0  東京じゃんがら ecute上野店  139.7771312  35.7140434        0  ラーメン屋
# 1    博多ラーメン 長浜や 上野店  139.7775269  35.7124554        0  ラーメン屋
# 2  T'sたんたん エキュート上野店  139.7771408  35.7140681        0  ラーメン屋
# 3     鯛塩そば灯花 アトレ上野店  139.7770178  35.7133078        0  ラーメン屋
# 4  横浜家系ラーメン 壱角家 上野店  139.7778759  35.7123833        0  ラーメン屋

# %%
df.tail()
# Out:
#            shop.name     shop.lon    shop.lat shop.alt name
# 25  焼肉ホルモン本舗 炎 上野駅前店  139.7762069  35.7112493        0  焼肉屋
# 26          肉の街 上野本店   139.775175   35.711006        0  焼肉屋
# 27          太昌園上野駅前店  139.7754445  35.7104037        0  焼肉屋
# 28             焼肉ひだり  139.7810698   35.711169        0  焼肉屋
# 29   土古里 上野バンブーガーデン店  139.7745426  35.7124233        0  焼肉屋

# %% [markdown]
# ### Note: RSS

# %%
pip install feedparser
# Out:
# Collecting feedparser
#   Downloading feedparser-6.0.12-py3-none-any.whl.metadata (2.7 kB)
# Collecting sgmllib3k (from feedparser)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Downloading feedparser-6.0.12-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 3.2 MB/s eta 0:00:00
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=1541cd6caebba99f57cc4f8f6cf94729b60c0b7e3c26f150920916fbe3f652b7
#   Stored in directory: /root/.cache/pip/wheels/03/f5/1a/23761066dac1d0e8e683e5fdb27e12de53209d05a4a37e6246
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
# Successfully installed feedparser-6.0.12 sgmllib3k-1.0.0

# %%
import feedparser

url = "https://blog.python.org/feeds/posts/default?alt=rss"
d = feedparser.parse(url)

# %%
d["feed"]["title"]  # RSSのタイトルを取得
# Out:
# 'Python Insider'

# %%
print(entry.keys())
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'id', 'guidislink', 'summary', 'summary_detail', 'published', 'published_parsed', 'authors', 'author', 'author_detail', 'tags'])

# %%
for entry in d.entries:
    print(entry.date, end=", ")  # エントリーの日付を出力
    print(entry.title)  # エントリーごとのタイトルを出力
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/feedparser/util.py in __getattr__(self, key)
#     155         try:
# --> 156             return self.__getitem__(key)
#     157         except KeyError:
#
# /usr/local/lib/python3.12/dist-packages/feedparser/util.py in __getitem__(self, key)
#     112                 return dict.__getitem__(self, realkey)
# --> 113         return dict.__getitem__(self, key)
#     114
#
# KeyError: 'date'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_39772/2808170523.py in <cell line: 0>()
#       1 for entry in d.entries:
# ----> 2     print(entry.date, end=", ")  # エントリーの日付を出力
#       3     print(entry.title)  # エントリーごとのタイトルを出力
#
# /usr/local/lib/python3.12/dist-packages/feedparser/util.py in __getattr__(self, key)
#     156             return self.__getitem__(key)
#     157         except KeyError:
# --> 158             raise AttributeError("object has no attribute '%s'" % key)
#     159
#     160     def __hash__(self):
#
# AttributeError: object has no attribute 'date'
